# %%
import numpy as np
import pandas as pd

# %%
#Generate correlation matrix

def gen_cov_matrix(p):

    P = p # number of features/variables in the data set (complexity)
    a = np.random.rand(P, P)
    m = np.tril(a) + np.tril(a, -1).T
    B = np.dot(m, m.transpose())

    corr_matrix = pd.DataFrame(B).cov()

    return corr_matrix

cov_matrix = gen_cov_matrix(100)

# %%
#Check whether the correlation matrix is positive definite

def positive_definite(matrix):
    sign, determinant = np.linalg.slogdet(matrix)
    
    if sign <= 0:
        print('Matrix is not positive definite')
    else:
        print('Matrix is positive definite')

positive_definite(cov_matrix)
# Out:
# Matrix is positive definite

# %%
# Generate covariates from a normal distribution using the covariance matrix
def gen_covariates(p, cov_matrix, N):
       
    mean=np.zeros(p, dtype=int)
    X = np.random.default_rng().multivariate_normal(mean, cov_matrix, N)
    covariates = pd.DataFrame(X)

    return covariates

df = gen_covariates(100, cov_matrix, 5000)

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0    -2.671343 -1.503669  0.937797 -2.279634 -0.861206  0.200599  1.314966
# 1    -1.320323  0.360625  0.248138  0.160705 -0.218016 -0.296850  0.784294
# 2    -0.340237  0.276360  0.226654  0.781352  1.684871  1.952999  1.046140
# 3     0.240315  0.877504  0.050675  1.996722 -0.166475 -0.482937  1.388533
# 4    -1.343041 -0.339975 -0.792166 -0.934717 -0.974391 -1.147260  0.124454
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995 -0.507962 -1.148894 -0.478338 -0.297600 -1.021333 -1.489321 -0.402382
# 4996 -1.139612 -1.335080 -1.043530 -1.495607 -1.461631 -0.934986 -1.077819
# 4997 -2.452434 -2.092165 -0.048455 -0.315142  0.345258  1.254836 -2.599510
# 4998  0.012595  1.642149  1.765716  0.970578  2.228275  1.302372  3.010499
# 4999 -2.295157 -2.803187 -1.410340 -1.489904 -4.628506 -3.361964 -3.696477
#
#             7         8         9   ...        90        91        92  \
# 0     0.552071 -1.961065  0.098347  ...  0.559362 -1.413859 -0.052935
# 1    -0.602471 -1.790049  1.318529  ...  1.156445 -0.278981  0.603288
# 2     3.212160  0.631776  1.825314  ... -0.699947  1.269773  1.636192
# 3     1.134043  0.363024  1.033928  ...  0.038980  1.272222  0.198470
# 4    -2.429672 -1.149572  0.481609  ...  0.419364 -0.572957 -0.470653
# ...        ...       ...       ...  ...       ...       ...       ...
# 4995 -2.917226 -0.366409 -2.452660  ...  0.288532 -0.879933 -2.328589
# 4996 -4.007633 -3.100511  0.285026  ... -0.262859 -1.450953 -1.049619
# 4997 -1.220531 -0.721472 -2.027436  ...  0.505155  0.114565 -4.220245
# 4998  1.020230  1.105026  2.668661  ...  0.460319  1.021988  2.707403
# 4999 -3.178099 -3.246753 -2.314616  ... -2.021350 -2.622814 -2.605782
#
#             93        94        95        96        97        98        99
# 0    -0.629619  0.508034 -1.845997 -2.356311 -1.411676  0.445476 -2.133587
# 1    -1.174740 -0.043022 -0.845515 -3.081532  0.438660 -0.349310 -1.166774
# 2    -0.509236  0.610978  2.177012 -0.352056  0.931464  0.492531 -0.346416
# 3    -0.467900  1.412499  0.208662  1.630980 -1.329527  0.987231  0.220035
# 4    -1.041730 -1.176200 -1.955684 -1.332342  1.032394 -0.884257 -0.313666
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995 -2.276038 -0.584173 -0.025721 -0.330606 -0.051966 -0.532828 -1.988340
# 4996 -1.443631 -0.919897 -0.193945 -2.460779 -2.365116 -1.790626  0.265714
# 4997 -1.410397 -3.049226 -0.845527 -0.962365 -1.122502 -2.600668 -1.728437
# 4998  1.233567  0.660367  0.190382  0.540321  0.255670  0.642507  1.920099
# 4999 -1.588989 -2.097985 -3.598436 -3.665029 -2.720480 -1.706737 -2.665666
#
# [5000 rows x 100 columns]
